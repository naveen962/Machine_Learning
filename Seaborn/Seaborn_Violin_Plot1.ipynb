# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
# Import Data
dataset = sns.load_dataset("tips")

# Construct plot
sns.violinplot(x = "sex", y = "total_bill", data =dataset)
plt.show()
